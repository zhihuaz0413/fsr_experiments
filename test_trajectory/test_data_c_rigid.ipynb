# %%
import FSRmsg_pb2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_dir = '/home/hrg/ws_moveit/data/short_rigid_letters/'

def show_fsrmsg(fsr_data_msg, title):
  len_frames = len(fsr_data_msg)
  all_layer1 = np.zeros((len_frames,16,16), dtype=np.int32)
  all_layer2 = np.zeros((len_frames,16,16), dtype=np.int32)
  for i in range(len_frames):
      data = fsr_data_msg[i]
      value = data.value
      ts = data.timestamp
      fsr_data = np.fromstring(value, dtype=int, sep=' ')
      fsr_data = fsr_data.reshape(16, 32)
      all_layer1[i] = fsr_data[:, 0:16]
      all_layer2[i] = fsr_data[:, 16:]
  mean_layer1 = all_layer1.mean(axis=0)
  mean_layer2 = all_layer2.mean(axis=0)
  vmin = min(np.min(mean_layer1), np.min(mean_layer2))
  vmax = max(np.max(mean_layer1), np.max(mean_layer2))
  std_layer1 = all_layer1.std(axis=0)
  std_layer2 = all_layer2.std(axis=0)
  s_vmin = min(np.min(std_layer1), np.min(std_layer2))
  s_vmax = max(np.max(std_layer1), np.max(std_layer2))
  fig, axs = plt.subplots(2, 2, figsize=(12, 12))
  pcm = axs[0, 0].imshow(mean_layer1, cmap='viridis', interpolation='none')#, vmin=vmin, vmax=vmax
  fig.colorbar(pcm, ax=axs[0, 0])
  axs[0, 0].set_title('mean layer1')
  pcm = axs[0, 1].imshow(mean_layer2, cmap='viridis', interpolation='none')#, vmin=vmin, vmax=vmax)
  fig.colorbar(pcm, ax=axs[0, 1])
  axs[0, 1].set_title('mean layer2')
  pcm = axs[1, 0].imshow(std_layer1, cmap='viridis', interpolation='none')#, vmin=s_vmin, vmax=s_vmax)
  fig.colorbar(pcm, ax=axs[1, 0])
  axs[1, 0].set_title('std layer1')
  pcm = axs[1, 1].imshow(std_layer2, cmap='viridis', interpolation='none')#, vmin=s_vmin, vmax=s_vmax)
  fig.colorbar(pcm, ax=axs[1, 1])
  axs[1, 1].set_title('std layer2')
  fig.suptitle(title)
  return mean_layer1, mean_layer2, std_layer1, std_layer2

def read_fsr_msg(file_f):
  fsrmsg = FSRmsg_pb2.FSRMsg()
  read_folder = data_dir + 'fsr/' + file_f
  with open(read_folder, "rb") as f:
    fsrmsg.ParseFromString(f.read())
  print(file_f, ' data length:', len(fsrmsg.fsr_data))
  return fsrmsg

# %%
import glob
fsr_data_all = glob.glob(data_dir + 'fsr/*.bin')
fsr_data_all = [os.path.basename(f) for f in fsr_data_all]
fsr_data_all.sort()
print(fsr_data_all)
fsr_calib_data = glob.glob(data_dir + 'fsr/calib/*.bin')
fsr_calib_data = [os.path.basename(f) for f in fsr_calib_data]
fsr_calib_data.sort()
print(fsr_calib_data)
print(len(fsr_data_all), len(fsr_calib_data))
# Out:
# ['c_rigid_concave_0.bin', 'c_rigid_concave_1.bin', 'c_rigid_concave_10.bin', 'c_rigid_concave_11.bin', 'c_rigid_concave_12.bin', 'c_rigid_concave_13.bin', 'c_rigid_concave_14.bin', 'c_rigid_concave_15.bin', 'c_rigid_concave_16.bin', 'c_rigid_concave_17.bin', 'c_rigid_concave_18.bin', 'c_rigid_concave_19.bin', 'c_rigid_concave_2.bin', 'c_rigid_concave_20.bin', 'c_rigid_concave_21.bin', 'c_rigid_concave_22.bin', 'c_rigid_concave_23.bin', 'c_rigid_concave_24.bin', 'c_rigid_concave_25.bin', 'c_rigid_concave_26.bin', 'c_rigid_concave_27.bin', 'c_rigid_concave_28.bin', 'c_rigid_concave_29.bin', 'c_rigid_concave_3.bin', 'c_rigid_concave_30.bin', 'c_rigid_concave_31.bin', 'c_rigid_concave_32.bin', 'c_rigid_concave_33.bin', 'c_rigid_concave_34.bin', 'c_rigid_concave_35.bin', 'c_rigid_concave_36.bin', 'c_rigid_concave_37.bin', 'c_rigid_concave_38.bin', 'c_rigid_concave_39.bin', 'c_rigid_concave_4.bin', 'c_rigid_concave_40.bin', 'c_rigid_concave_41.bin', 'c_rigid_concave_42.bin', 'c_rigid_concave_43.bin', 'c_rigid_concave_44.bin', 'c_rigid_concave_45.bin', 'c_rigid_concave_46.bin', 'c_rigid_concave_47.bin', 'c_rigid_concave_48.bin', 'c_rigid_concave_49.bin', 'c_rigid_concave_5.bin', 'c_rigid_concave_6.bin', 'c_rigid_concave_7.bin', 'c_rigid_concave_8.bin', 'c_rigid_concave_9.bin', 'c_rigid_convex_0.bin', 'c_rigid_convex_1.bin', 'c_rigid_convex_10.bin', 'c_rigid_convex_11.bin', 'c_rigid_convex_12.bin', 'c_rigid_convex_13.bin', 'c_rigid_convex_14.bin', 'c_rigid_convex_15.bin', 'c_rigid_convex_16.bin', 'c_rigid_convex_17.bin', 'c_rigid_convex_18.bin', 'c_rigid_convex_19.bin', 'c_rigid_convex_2.bin', 'c_rigid_convex_20.bin', 'c_rigid_convex_21.bin', 'c_rigid_convex_22.bin', 'c_rigid_convex_23.bin', 'c_rigid_convex_24.bin', 'c_rigid_convex_25.bin', 'c_rigid_convex_26.bin', 'c_rigid_convex_27.bin', 'c_rigid_convex_28.bin', 'c_rigid_convex_29.bin', 'c_rigid_convex_3.bin', 'c_rigid_convex_30.bin', 'c_rigid_convex_31.bin', 'c_rigid_convex_32.bin', 'c_rigid_convex_33.bin', 'c_rigid_convex_34.bin', 'c_rigid_convex_35.bin', 'c_rigid_convex_36.bin', 'c_rigid_convex_37.bin', 'c_rigid_convex_38.bin', 'c_rigid_convex_39.bin', 'c_rigid_convex_4.bin', 'c_rigid_convex_40.bin', 'c_rigid_convex_41.bin', 'c_rigid_convex_42.bin', 'c_rigid_convex_43.bin', 'c_rigid_convex_44.bin', 'c_rigid_convex_45.bin', 'c_rigid_convex_46.bin', 'c_rigid_convex_47.bin', 'c_rigid_convex_48.bin', 'c_rigid_convex_49.bin', 'c_rigid_convex_5.bin', 'c_rigid_convex_6.bin', 'c_rigid_convex_7.bin', 'c_rigid_convex_8.bin', 'c_rigid_convex_9.bin', 'c_rigid_flat_0.bin', 'c_rigid_flat_1.bin', 'c_rigid_flat_10.bin', 'c_rigid_flat_11.bin', 'c_rigid_flat_12.bin', 'c_rigid_flat_13.bin', 'c_rigid_flat_14.bin', 'c_rigid_flat_15.bin', 'c_rigid_flat_16.bin', 'c_rigid_flat_17.bin', 'c_rigid_flat_18.bin', 'c_rigid_flat_19.bin', 'c_rigid_flat_2.bin', 'c_rigid_flat_20.bin', 'c_rigid_flat_21.bin', 'c_rigid_flat_22.bin', 'c_rigid_flat_23.bin', 'c_rigid_flat_24.bin', 'c_rigid_flat_25.bin', 'c_rigid_flat_26.bin', 'c_rigid_flat_27.bin', 'c_rigid_flat_28.bin', 'c_rigid_flat_29.bin', 'c_rigid_flat_3.bin', 'c_rigid_flat_30.bin', 'c_rigid_flat_31.bin', 'c_rigid_flat_32.bin', 'c_rigid_flat_33.bin', 'c_rigid_flat_34.bin', 'c_rigid_flat_35.bin', 'c_rigid_flat_36.bin', 'c_rigid_flat_37.bin', 'c_rigid_flat_38.bin', 'c_rigid_flat_39.bin', 'c_rigid_flat_4.bin', 'c_rigid_flat_40.bin', 'c_rigid_flat_41.bin', 'c_rigid_flat_42.bin', 'c_rigid_flat_43.bin', 'c_rigid_flat_44.bin', 'c_rigid_flat_45.bin', 'c_rigid_flat_46.bin', 'c_rigid_flat_47.bin', 'c_rigid_flat_48.bin', 'c_rigid_flat_49.bin', 'c_rigid_flat_5.bin', 'c_rigid_flat_6.bin', 'c_rigid_flat_7.bin', 'c_rigid_flat_8.bin', 'c_rigid_flat_9.bin']
# ['c_rigid_concave_0_calib.bin', 'c_rigid_concave_10_calib.bin', 'c_rigid_concave_11_calib.bin', 'c_rigid_concave_12_calib.bin', 'c_rigid_concave_13_calib.bin', 'c_rigid_concave_14_calib.bin', 'c_rigid_concave_15_calib.bin', 'c_rigid_concave_16_calib.bin', 'c_rigid_concave_17_calib.bin', 'c_rigid_concave_18_calib.bin', 'c_rigid_concave_19_calib.bin', 'c_rigid_concave_1_calib.bin', 'c_rigid_concave_20_calib.bin', 'c_rigid_concave_21_calib.bin', 'c_rigid_concave_22_calib.bin', 'c_rigid_concave_23_calib.bin', 'c_rigid_concave_24_calib.bin', 'c_rigid_concave_25_calib.bin', 'c_rigid_concave_26_calib.bin', 'c_rigid_concave_27_calib.bin', 'c_rigid_concave_28_calib.bin', 'c_rigid_concave_29_calib.bin', 'c_rigid_concave_2_calib.bin', 'c_rigid_concave_30_calib.bin', 'c_rigid_concave_31_calib.bin', 'c_rigid_concave_32_calib.bin', 'c_rigid_concave_33_calib.bin', 'c_rigid_concave_34_calib.bin', 'c_rigid_concave_35_calib.bin', 'c_rigid_concave_36_calib.bin', 'c_rigid_concave_37_calib.bin', 'c_rigid_concave_38_calib.bin', 'c_rigid_concave_39_calib.bin', 'c_rigid_concave_3_calib.bin', 'c_rigid_concave_40_calib.bin', 'c_rigid_concave_41_calib.bin', 'c_rigid_concave_42_calib.bin', 'c_rigid_concave_43_calib.bin', 'c_rigid_concave_44_calib.bin', 'c_rigid_concave_45_calib.bin', 'c_rigid_concave_46_calib.bin', 'c_rigid_concave_47_calib.bin', 'c_rigid_concave_48_calib.bin', 'c_rigid_concave_49_calib.bin', 'c_rigid_concave_4_calib.bin', 'c_rigid_concave_5_calib.bin', 'c_rigid_concave_6_calib.bin', 'c_rigid_concave_7_calib.bin', 'c_rigid_concave_8_calib.bin', 'c_rigid_concave_9_calib.bin', 'c_rigid_convex_0_calib.bin', 'c_rigid_convex_10_calib.bin', 'c_rigid_convex_11_calib.bin', 'c_rigid_convex_12_calib.bin', 'c_rigid_convex_13_calib.bin', 'c_rigid_convex_14_calib.bin', 'c_rigid_convex_15_calib.bin', 'c_rigid_convex_16_calib.bin', 'c_rigid_convex_17_calib.bin', 'c_rigid_convex_18_calib.bin', 'c_rigid_convex_19_calib.bin', 'c_rigid_convex_1_calib.bin', 'c_rigid_convex_20_calib.bin', 'c_rigid_convex_21_calib.bin', 'c_rigid_convex_22_calib.bin', 'c_rigid_convex_23_calib.bin', 'c_rigid_convex_24_calib.bin', 'c_rigid_convex_25_calib.bin', 'c_rigid_convex_26_calib.bin', 'c_rigid_convex_27_calib.bin', 'c_rigid_convex_28_calib.bin', 'c_rigid_convex_29_calib.bin', 'c_rigid_convex_2_calib.bin', 'c_rigid_convex_30_calib.bin', 'c_rigid_convex_31_calib.bin', 'c_rigid_convex_32_calib.bin', 'c_rigid_convex_33_calib.bin', 'c_rigid_convex_34_calib.bin', 'c_rigid_convex_35_calib.bin', 'c_rigid_convex_36_calib.bin', 'c_rigid_convex_37_calib.bin', 'c_rigid_convex_38_calib.bin', 'c_rigid_convex_39_calib.bin', 'c_rigid_convex_3_calib.bin', 'c_rigid_convex_40_calib.bin', 'c_rigid_convex_41_calib.bin', 'c_rigid_convex_42_calib.bin', 'c_rigid_convex_43_calib.bin', 'c_rigid_convex_44_calib.bin', 'c_rigid_convex_45_calib.bin', 'c_rigid_convex_46_calib.bin', 'c_rigid_convex_47_calib.bin', 'c_rigid_convex_48_calib.bin', 'c_rigid_convex_49_calib.bin', 'c_rigid_convex_4_calib.bin', 'c_rigid_convex_5_calib.bin', 'c_rigid_convex_6_calib.bin', 'c_rigid_convex_7_calib.bin', 'c_rigid_convex_8_calib.bin', 'c_rigid_convex_9_calib.bin', 'c_rigid_flat_0_calib.bin', 'c_rigid_flat_10_calib.bin', 'c_rigid_flat_11_calib.bin', 'c_rigid_flat_12_calib.bin', 'c_rigid_flat_13_calib.bin', 'c_rigid_flat_14_calib.bin', 'c_rigid_flat_15_calib.bin', 'c_rigid_flat_16_calib.bin', 'c_rigid_flat_17_calib.bin', 'c_rigid_flat_18_calib.bin', 'c_rigid_flat_19_calib.bin', 'c_rigid_flat_1_calib.bin', 'c_rigid_flat_20_calib.bin', 'c_rigid_flat_21_calib.bin', 'c_rigid_flat_22_calib.bin', 'c_rigid_flat_23_calib.bin', 'c_rigid_flat_24_calib.bin', 'c_rigid_flat_25_calib.bin', 'c_rigid_flat_26_calib.bin', 'c_rigid_flat_27_calib.bin', 'c_rigid_flat_28_calib.bin', 'c_rigid_flat_29_calib.bin', 'c_rigid_flat_2_calib.bin', 'c_rigid_flat_30_calib.bin', 'c_rigid_flat_31_calib.bin', 'c_rigid_flat_32_calib.bin', 'c_rigid_flat_33_calib.bin', 'c_rigid_flat_34_calib.bin', 'c_rigid_flat_35_calib.bin', 'c_rigid_flat_36_calib.bin', 'c ...
# 150 150

# %%
c_rigid_concave = []
c_rigid_convex = []
c_rigid_flat = []
c_rigid_wave = []
for file_f in fsr_data_all:
  if '_concave' in file_f:
    c_rigid_concave.append(file_f)
  elif '_convex' in file_f:
    c_rigid_convex.append(file_f)
  elif '_flat' in file_f:
    c_rigid_flat.append(file_f)
  elif '_wave' in file_f:
    c_rigid_wave.append(file_f)

# %%
test_data = c_rigid_concave[0] #c_rigid_concave[0]
test_calib_data = test_data.replace('.bin', '_calib.bin')
print(test_data, test_calib_data)

calib_fsrmsg = read_fsr_msg('calib/' + test_calib_data)
fsrmsg = read_fsr_msg(test_data)

len_frames = len(fsrmsg.fsr_data)
print('calib data length:', len(calib_fsrmsg.fsr_data), 'test data length:', len_frames)
# Out:
# c_rigid_concave_0.bin c_rigid_concave_0_calib.bin
# calib/c_rigid_concave_0_calib.bin  data length: 174
# c_rigid_concave_0.bin  data length: 1430
# calib data length: 174 test data length: 1430

# %%
calib_layer1, calib_layer2, std_layer1, std_layer2 = show_fsrmsg(calib_fsrmsg.fsr_data, test_calib_data)

# %%
mean_layer1_0, mean_layer2_0, std_layer1_0, std_layer2_0 = show_fsrmsg(fsrmsg.fsr_data, test_data)

# %%
kinova_data = glob.glob(data_dir + 'kinova/*')
kinova_data = [os.path.basename(f) for f in kinova_data]
kinova_data.sort()
print(kinova_data)
# Out:
# ['c_rigid_concave_cmd_precision_0.csv', 'c_rigid_concave_cmd_precision_1.csv', 'c_rigid_concave_cmd_precision_10.csv', 'c_rigid_concave_cmd_precision_11.csv', 'c_rigid_concave_cmd_precision_12.csv', 'c_rigid_concave_cmd_precision_13.csv', 'c_rigid_concave_cmd_precision_14.csv', 'c_rigid_concave_cmd_precision_15.csv', 'c_rigid_concave_cmd_precision_16.csv', 'c_rigid_concave_cmd_precision_17.csv', 'c_rigid_concave_cmd_precision_18.csv', 'c_rigid_concave_cmd_precision_19.csv', 'c_rigid_concave_cmd_precision_2.csv', 'c_rigid_concave_cmd_precision_20.csv', 'c_rigid_concave_cmd_precision_21.csv', 'c_rigid_concave_cmd_precision_22.csv', 'c_rigid_concave_cmd_precision_23.csv', 'c_rigid_concave_cmd_precision_24.csv', 'c_rigid_concave_cmd_precision_25.csv', 'c_rigid_concave_cmd_precision_26.csv', 'c_rigid_concave_cmd_precision_27.csv', 'c_rigid_concave_cmd_precision_28.csv', 'c_rigid_concave_cmd_precision_29.csv', 'c_rigid_concave_cmd_precision_3.csv', 'c_rigid_concave_cmd_precision_30.csv', 'c_rigid_concave_cmd_precision_31.csv', 'c_rigid_concave_cmd_precision_32.csv', 'c_rigid_concave_cmd_precision_33.csv', 'c_rigid_concave_cmd_precision_34.csv', 'c_rigid_concave_cmd_precision_35.csv', 'c_rigid_concave_cmd_precision_36.csv', 'c_rigid_concave_cmd_precision_37.csv', 'c_rigid_concave_cmd_precision_38.csv', 'c_rigid_concave_cmd_precision_39.csv', 'c_rigid_concave_cmd_precision_4.csv', 'c_rigid_concave_cmd_precision_40.csv', 'c_rigid_concave_cmd_precision_41.csv', 'c_rigid_concave_cmd_precision_42.csv', 'c_rigid_concave_cmd_precision_43.csv', 'c_rigid_concave_cmd_precision_44.csv', 'c_rigid_concave_cmd_precision_45.csv', 'c_rigid_concave_cmd_precision_46.csv', 'c_rigid_concave_cmd_precision_47.csv', 'c_rigid_concave_cmd_precision_48.csv', 'c_rigid_concave_cmd_precision_49.csv', 'c_rigid_concave_cmd_precision_5.csv', 'c_rigid_concave_cmd_precision_6.csv', 'c_rigid_concave_cmd_precision_7.csv', 'c_rigid_concave_cmd_precision_8.csv', 'c_rigid_concave_cmd_precision_9.csv', 'c_rigid_concave_cmd_pressing_0.csv', 'c_rigid_concave_cmd_pressing_1.csv', 'c_rigid_concave_cmd_pressing_10.csv', 'c_rigid_concave_cmd_pressing_11.csv', 'c_rigid_concave_cmd_pressing_12.csv', 'c_rigid_concave_cmd_pressing_13.csv', 'c_rigid_concave_cmd_pressing_14.csv', 'c_rigid_concave_cmd_pressing_15.csv', 'c_rigid_concave_cmd_pressing_16.csv', 'c_rigid_concave_cmd_pressing_17.csv', 'c_rigid_concave_cmd_pressing_18.csv', 'c_rigid_concave_cmd_pressing_19.csv', 'c_rigid_concave_cmd_pressing_2.csv', 'c_rigid_concave_cmd_pressing_20.csv', 'c_rigid_concave_cmd_pressing_21.csv', 'c_rigid_concave_cmd_pressing_22.csv', 'c_rigid_concave_cmd_pressing_23.csv', 'c_rigid_concave_cmd_pressing_24.csv', 'c_rigid_concave_cmd_pressing_25.csv', 'c_rigid_concave_cmd_pressing_26.csv', 'c_rigid_concave_cmd_pressing_27.csv', 'c_rigid_concave_cmd_pressing_28.csv', 'c_rigid_concave_cmd_pressing_29.csv', 'c_rigid_concave_cmd_pressing_3.csv', 'c_rigid_concave_cmd_pressing_30.csv', 'c_rigid_concave_cmd_pressing_31.csv', 'c_rigid_concave_cmd_pressing_32.csv', 'c_rigid_concave_cmd_pressing_33.csv', 'c_rigid_concave_cmd_pressing_34.csv', 'c_rigid_concave_cmd_pressing_35.csv', 'c_rigid_concave_cmd_pressing_36.csv', 'c_rigid_concave_cmd_pressing_37.csv', 'c_rigid_concave_cmd_pressing_38.csv', 'c_rigid_concave_cmd_pressing_39.csv', 'c_rigid_concave_cmd_pressing_4.csv', 'c_rigid_concave_cmd_pressing_40.csv', 'c_rigid_concave_cmd_pressing_41.csv', 'c_rigid_concave_cmd_pressing_42.csv', 'c_rigid_concave_cmd_pressing_43.csv', 'c_rigid_concave_cmd_pressing_44.csv', 'c_rigid_concave_cmd_pressing_45.csv', 'c_rigid_concave_cmd_pressing_46.csv', 'c_rigid_concave_cmd_pressing_47.csv', 'c_rigid_concave_cmd_pressing_48.csv', 'c_rigid_concave_cmd_pressing_49.csv', 'c_rigid_concave_cmd_pressing_5.csv', 'c_rigid_concave_cmd_pressing_6.csv', 'c_rigid_concave_cmd_pressing_7.csv', 'c_rigid_concave_cmd_pressing_8.csv', 'c_rigid_concave_cmd_pressing_9.csv', 'c_rigid_concave_cmd_slipping_0.csv', 'c_rigid_concave_cmd_slipping_1 ...

# %%
labels = test_data.split('.')[0].split('_')
print(labels)
cmd_pressing = labels[0] + '_' + labels[1] + '_' + labels[2] + '_cmd_pressing_' + labels[3] + '.csv'
cmd_precision = labels[0] + '_' + labels[1] + '_' + labels[2] + '_cmd_precision_' + labels[3] + '.csv'
cmd_slipping = labels[0] + '_' + labels[1] + '_' + labels[2] + '_cmd_slipping_' + labels[3] + '.csv'
print(cmd_pressing, cmd_precision, cmd_slipping)
# Out:
# ['c', 'rigid', 'concave', '0']
# c_rigid_concave_cmd_pressing_0.csv c_rigid_concave_cmd_precision_0.csv c_rigid_concave_cmd_slipping_0.csv

# %%
from numpy import genfromtxt
cmd_dir = data_dir + 'kinova/'
test_cmd_pressing = genfromtxt(cmd_dir + cmd_pressing, delimiter=',')
test_cmd_precision = genfromtxt(cmd_dir + cmd_precision, delimiter=',')
test_cmd_slipping = genfromtxt(cmd_dir + cmd_slipping, delimiter=',')
print(test_cmd_pressing.shape, test_cmd_precision.shape, test_cmd_slipping.shape)
# Out:
# (636, 7) (796, 7) (1590, 7)

# %%
t_start = test_cmd_pressing[0, 0]
t_end = test_cmd_pressing[-1, 0]
print(t_start, t_end)

start_idx = -1
end_idx = -1

for i in range(len(fsrmsg.fsr_data)):
    if start_idx == -1 and int(fsrmsg.fsr_data[i].timestamp) > t_start:
        start_idx = i
    if end_idx == -1 and int(fsrmsg.fsr_data[i].timestamp) > t_end:
        end_idx = i
        break
data_pressing = fsrmsg.fsr_data[start_idx:end_idx]
print(start_idx, end_idx)
# Out:
# 1.7193211149930877e+18 1.7193211214528591e+18
# 312 537

# %%
mean_layer1_pressing, mean_layer2_pressing, std_layer1_pressing, std_layer2_pressing = show_fsrmsg(data_pressing, test_data + ' pressing')

# %%
len_pressing = len(data_pressing)
print('pressing data length:', len_pressing)
sample_num = int(len_pressing / 10)
print('sample num:', sample_num)
sample_data = data_pressing[::sample_num]
print('sample data length:', len(sample_data))
ts_start = float(int(data_pressing[0].timestamp) * (10**-9))
print('ts_start:', ts_start)
# Out:
# pressing data length: 225
# sample num: 22
# sample data length: 11
# ts_start: 1719321115.011541

# %%
# visualize the data according to the timestamp
from mpl_toolkits.axes_grid1 import make_axes_locatable

ts_bins = [(float(int(data.timestamp) * (10**-9)) - ts_start) for data in sample_data]
fig, axs = plt.subplots(len(ts_bins), 2, figsize=(12, 6*len(ts_bins)))
# fig.subplots_adjust(left=0.02, bottom=0.06, right=0.95, top=0.94, wspace=0.05)

for i in range(len(ts_bins)):
    value = sample_data[i].value
    ts = ts_bins[i]
    fsr_data = np.fromstring(value, dtype=int, sep=' ')
    fsr_data = fsr_data.reshape(16, 32)
    layer_1 = fsr_data[:, 0:16] - calib_layer1
    layer_2 = fsr_data[:, 16:] - calib_layer2
    min_val_1 = np.min(fsr_data[:, 0:16])
    max_val_1 = np.max(fsr_data[:, 0:16])
    min_val_2 = np.min(fsr_data[:, 16:])
    max_val_2 = np.max(fsr_data[:, 16:])

    im = axs[i, 0].imshow(layer_1, cmap='viridis', interpolation='none', vmin=min_val_1, vmax=max_val_1)
    im2 = axs[i, 1].imshow(layer_2, cmap='viridis', interpolation='none', vmin=min_val_2, vmax=max_val_2)
    axs[i, 0].set_title('layer1 ts: ' + str(ts))
    axs[i, 1].set_title('layer2 ts: ' + str(ts))
    fig.colorbar(im, ax=axs[i, 0])
    fig.colorbar(im2, ax=axs[i, 1])
# fig.colorbar(im, ax=axs.ravel().tolist(), orientation='horizontal', fraction=0.05, pad=0.05)
# plt.title('FSR data')

# %%
t_start = test_cmd_precision[0, 0]
t_end = test_cmd_precision[-1, 0]
print(t_start, t_end)

start_idx = -1
end_idx = -1

for i in range(len(fsrmsg.fsr_data)):
    if start_idx == -1 and int(fsrmsg.fsr_data[i].timestamp) > t_start:
        start_idx = i
    if end_idx == -1 and int(fsrmsg.fsr_data[i].timestamp) > t_end:
        end_idx = i
        break
data_precision = fsrmsg.fsr_data[start_idx:end_idx]
print(start_idx, end_idx)
mean_layer1_precision, mean_layer2_precision, std_layer1_precision, std_layer2_precision = show_fsrmsg(data_precision, test_data + ' precision')
# Out:
# 1.7193211214632945e+18 1.719321129557069e+18
# 538 820

# %%
len_precision = len(data_precision)
print('precision data length:', len_precision)
sample_num = int(len_precision / 10)
print('sample num:', sample_num)
sample_data = data_precision[::sample_num]
print('sample data length:', len(sample_data))
ts_start = float(int(data_precision[0].timestamp) * (10**-9))
print('ts_start:', ts_start)

ts_bins = [(float(int(data.timestamp) * (10**-9)) - ts_start) for data in sample_data]
fig, axs = plt.subplots(len(ts_bins), 2, figsize=(12, 6*len(ts_bins)))
# fig.subplots_adjust(left=0.02, bottom=0.06, right=0.95, top=0.94, wspace=0.05)

for i in range(len(ts_bins)):
    value = sample_data[i].value
    ts = ts_bins[i]
    fsr_data = np.fromstring(value, dtype=int, sep=' ')
    fsr_data = fsr_data.reshape(16, 32)
    layer_1 = fsr_data[:, 0:16] - calib_layer1
    layer_2 = fsr_data[:, 16:] - calib_layer2
    min_val_1 = np.min(fsr_data[:, 0:16])
    max_val_1 = np.max(fsr_data[:, 0:16])
    min_val_2 = np.min(fsr_data[:, 16:])
    max_val_2 = np.max(fsr_data[:, 16:])

    im = axs[i, 0].imshow(layer_1, cmap='viridis', interpolation='none', vmin=min_val_1, vmax=max_val_1)
    im2 = axs[i, 1].imshow(layer_2, cmap='viridis', interpolation='none', vmin=min_val_2, vmax=max_val_2)
    axs[i, 0].set_title('layer1 ts: ' + str(ts))
    axs[i, 1].set_title('layer2 ts: ' + str(ts))
    fig.colorbar(im, ax=axs[i, 0])
    fig.colorbar(im2, ax=axs[i, 1])
# Out:
# precision data length: 282
# sample num: 28
# sample data length: 11
# ts_start: 1719321121.4910421

# %%
t_start = test_cmd_slipping[0, 0]
t_end = test_cmd_slipping[-1, 0]
print(t_start, t_end)

start_idx = -1
end_idx = -1

for i in range(len(fsrmsg.fsr_data)):
    if start_idx == -1 and int(fsrmsg.fsr_data[i].timestamp) > t_start:
        start_idx = i
    if end_idx == -1 and int(fsrmsg.fsr_data[i].timestamp) > t_end:
        end_idx = i
        break
data_slipping = fsrmsg.fsr_data[start_idx:end_idx]
print(start_idx, end_idx)
mean_layer1_slipping, mean_layer2_slipping, std_layer1_slipping, std_layer2_slipping = show_fsrmsg(data_precision, test_data + ' slipping')
# Out:
# 1.7193211295675397e+18 1.719321145742234e+18
# 820 1384

# %%
len_slipping = len(data_slipping)
print('precision data length:', len_slipping)
sample_num = int(len_slipping / 15)
print('sample num:', sample_num)
sample_data = data_slipping[::sample_num]
print('sample data length:', len(sample_data))
ts_start = float(int(data_slipping[0].timestamp) * (10**-9))
print('ts_start:', ts_start)

ts_bins = [(float(int(data.timestamp) * (10**-9)) - ts_start) for data in sample_data]
fig, axs = plt.subplots(len(ts_bins), 2, figsize=(12, 6*len(ts_bins)))
# fig.subplots_adjust(left=0.02, bottom=0.06, right=0.95, top=0.94, wspace=0.05)

for i in range(len(ts_bins)):
    value = sample_data[i].value
    ts = ts_bins[i]
    fsr_data = np.fromstring(value, dtype=int, sep=' ')
    fsr_data = fsr_data.reshape(16, 32)
    layer_1 = fsr_data[:, 0:16] - calib_layer1
    layer_2 = fsr_data[:, 16:] - calib_layer2
    min_val_1 = np.min(fsr_data[:, 0:16])
    max_val_1 = np.max(fsr_data[:, 0:16])
    min_val_2 = np.min(fsr_data[:, 16:])
    max_val_2 = np.max(fsr_data[:, 16:])

    im = axs[i, 0].imshow(layer_1, cmap='viridis', interpolation='none', vmin=min_val_1, vmax=max_val_1)
    im2 = axs[i, 1].imshow(layer_2, cmap='viridis', interpolation='none', vmin=min_val_2, vmax=max_val_2)
    axs[i, 0].set_title('layer1 ts: ' + str(ts))
    axs[i, 1].set_title('layer2 ts: ' + str(ts))
    fig.colorbar(im, ax=axs[i, 0])
    fig.colorbar(im2, ax=axs[i, 1])
# Out:
# precision data length: 564
# sample num: 37
# sample data length: 16
# ts_start: 1719321129.575784

# %%
force_data_all = glob.glob(data_dir + '/ni_daqmx/*.bin')
force_data_all = [os.path.basename(f) for f in fsr_data_all]
force_data_all.sort()
print(fsr_data_all)
# Out:
# ['c_rigid_concave_0.bin', 'c_rigid_concave_1.bin', 'c_rigid_concave_10.bin', 'c_rigid_concave_11.bin', 'c_rigid_concave_12.bin', 'c_rigid_concave_13.bin', 'c_rigid_concave_14.bin', 'c_rigid_concave_15.bin', 'c_rigid_concave_16.bin', 'c_rigid_concave_17.bin', 'c_rigid_concave_18.bin', 'c_rigid_concave_19.bin', 'c_rigid_concave_2.bin', 'c_rigid_concave_20.bin', 'c_rigid_concave_21.bin', 'c_rigid_concave_22.bin', 'c_rigid_concave_23.bin', 'c_rigid_concave_24.bin', 'c_rigid_concave_25.bin', 'c_rigid_concave_26.bin', 'c_rigid_concave_27.bin', 'c_rigid_concave_28.bin', 'c_rigid_concave_29.bin', 'c_rigid_concave_3.bin', 'c_rigid_concave_30.bin', 'c_rigid_concave_31.bin', 'c_rigid_concave_32.bin', 'c_rigid_concave_33.bin', 'c_rigid_concave_34.bin', 'c_rigid_concave_35.bin', 'c_rigid_concave_36.bin', 'c_rigid_concave_37.bin', 'c_rigid_concave_38.bin', 'c_rigid_concave_39.bin', 'c_rigid_concave_4.bin', 'c_rigid_concave_40.bin', 'c_rigid_concave_41.bin', 'c_rigid_concave_42.bin', 'c_rigid_concave_43.bin', 'c_rigid_concave_44.bin', 'c_rigid_concave_45.bin', 'c_rigid_concave_46.bin', 'c_rigid_concave_47.bin', 'c_rigid_concave_48.bin', 'c_rigid_concave_49.bin', 'c_rigid_concave_5.bin', 'c_rigid_concave_6.bin', 'c_rigid_concave_7.bin', 'c_rigid_concave_8.bin', 'c_rigid_concave_9.bin', 'c_rigid_convex_0.bin', 'c_rigid_convex_1.bin', 'c_rigid_convex_10.bin', 'c_rigid_convex_11.bin', 'c_rigid_convex_12.bin', 'c_rigid_convex_13.bin', 'c_rigid_convex_14.bin', 'c_rigid_convex_15.bin', 'c_rigid_convex_16.bin', 'c_rigid_convex_17.bin', 'c_rigid_convex_18.bin', 'c_rigid_convex_19.bin', 'c_rigid_convex_2.bin', 'c_rigid_convex_20.bin', 'c_rigid_convex_21.bin', 'c_rigid_convex_22.bin', 'c_rigid_convex_23.bin', 'c_rigid_convex_24.bin', 'c_rigid_convex_25.bin', 'c_rigid_convex_26.bin', 'c_rigid_convex_27.bin', 'c_rigid_convex_28.bin', 'c_rigid_convex_29.bin', 'c_rigid_convex_3.bin', 'c_rigid_convex_30.bin', 'c_rigid_convex_31.bin', 'c_rigid_convex_32.bin', 'c_rigid_convex_33.bin', 'c_rigid_convex_34.bin', 'c_rigid_convex_35.bin', 'c_rigid_convex_36.bin', 'c_rigid_convex_37.bin', 'c_rigid_convex_38.bin', 'c_rigid_convex_39.bin', 'c_rigid_convex_4.bin', 'c_rigid_convex_40.bin', 'c_rigid_convex_41.bin', 'c_rigid_convex_42.bin', 'c_rigid_convex_43.bin', 'c_rigid_convex_44.bin', 'c_rigid_convex_45.bin', 'c_rigid_convex_46.bin', 'c_rigid_convex_47.bin', 'c_rigid_convex_48.bin', 'c_rigid_convex_49.bin', 'c_rigid_convex_5.bin', 'c_rigid_convex_6.bin', 'c_rigid_convex_7.bin', 'c_rigid_convex_8.bin', 'c_rigid_convex_9.bin', 'c_rigid_flat_0.bin', 'c_rigid_flat_1.bin', 'c_rigid_flat_10.bin', 'c_rigid_flat_11.bin', 'c_rigid_flat_12.bin', 'c_rigid_flat_13.bin', 'c_rigid_flat_14.bin', 'c_rigid_flat_15.bin', 'c_rigid_flat_16.bin', 'c_rigid_flat_17.bin', 'c_rigid_flat_18.bin', 'c_rigid_flat_19.bin', 'c_rigid_flat_2.bin', 'c_rigid_flat_20.bin', 'c_rigid_flat_21.bin', 'c_rigid_flat_22.bin', 'c_rigid_flat_23.bin', 'c_rigid_flat_24.bin', 'c_rigid_flat_25.bin', 'c_rigid_flat_26.bin', 'c_rigid_flat_27.bin', 'c_rigid_flat_28.bin', 'c_rigid_flat_29.bin', 'c_rigid_flat_3.bin', 'c_rigid_flat_30.bin', 'c_rigid_flat_31.bin', 'c_rigid_flat_32.bin', 'c_rigid_flat_33.bin', 'c_rigid_flat_34.bin', 'c_rigid_flat_35.bin', 'c_rigid_flat_36.bin', 'c_rigid_flat_37.bin', 'c_rigid_flat_38.bin', 'c_rigid_flat_39.bin', 'c_rigid_flat_4.bin', 'c_rigid_flat_40.bin', 'c_rigid_flat_41.bin', 'c_rigid_flat_42.bin', 'c_rigid_flat_43.bin', 'c_rigid_flat_44.bin', 'c_rigid_flat_45.bin', 'c_rigid_flat_46.bin', 'c_rigid_flat_47.bin', 'c_rigid_flat_48.bin', 'c_rigid_flat_49.bin', 'c_rigid_flat_5.bin', 'c_rigid_flat_6.bin', 'c_rigid_flat_7.bin', 'c_rigid_flat_8.bin', 'c_rigid_flat_9.bin']

# %%
if test_data not in force_data_all:
    print('No corresponding force data:', test_data)

import niforce_pb2
def read_force_msg(file_f):
  force_msg = niforce_pb2.MsgForce()
  read_folder = data_dir + 'ni_daqmx/' + file_f
  with open(read_folder, "rb") as f:
    force_msg.ParseFromString(f.read())
  print(file_f, ' data length:', len(force_msg.force))
  return force_msg
force_data = read_force_msg(test_data)
# Out:
# c_rigid_concave_0.bin  data length: 568240

# %%
t_start = test_cmd_pressing[0, 0]
t_end = test_cmd_pressing[-1, 0]

start_idx = -1
end_idx = -1
for i in range(len(force_data.force)):
    if start_idx == -1 and int(force_data.force[i].timestamp.split('.')[0]) > t_start:
        start_idx = i
    if end_idx == -1 and int(force_data.force[i].timestamp.split('.')[0]) > t_end:
        end_idx = i
        break

force_pressing = force_data.force[start_idx:end_idx]
print(start_idx, end_idx)

force_data_np = np.zeros((len(force_pressing), 7))
for i in range(len(force_pressing)):
    data = force_pressing[i]
    force_data_np[i] = [int(data.timestamp.split('.')[0]), data.force.x, data.force.y, data.force.z, data.torque.x, data.torque.y, data.torque.z]

print(force_data_np.shape)
force_data_np[:, 0] = (force_data_np[:, 0] - force_data_np[0, 0]) * (10**-9)
fig, axs = plt.subplots(2, 3, figsize=(18, 10))
axs[0, 0].plot(force_data_np[:, 0], force_data_np[:, 1], label='Fx')
axs[0, 0].set_title('Fx')
axs[0, 1].plot(force_data_np[:, 0], force_data_np[:, 2], label='Fy')
axs[0, 1].set_title('Fy')
axs[0, 2].plot(force_data_np[:, 0], force_data_np[:, 3], label='Fz')
axs[0, 2].set_title('Fz')
axs[1, 0].plot(force_data_np[:, 0], force_data_np[:, 4], label='Tx')
axs[1, 0].set_title('Tx')
axs[1, 1].plot(force_data_np[:, 0], force_data_np[:, 5], label='Ty')
axs[1, 1].set_title('Ty')
axs[1, 2].plot(force_data_np[:, 0], force_data_np[:, 6], label='Tz')
axs[1, 2].set_title('Tz')
plt.show()
# Out:
# 172918 252830
# (79912, 7)

# %%
t_start = test_cmd_precision[0, 0]
t_end = test_cmd_precision[-1, 0]

start_idx = -1
end_idx = -1
for i in range(len(force_data.force)):
    if start_idx == -1 and int(force_data.force[i].timestamp.split('.')[0]) > t_start:
        start_idx = i
    if end_idx == -1 and int(force_data.force[i].timestamp.split('.')[0]) > t_end:
        end_idx = i
        break

force_precision = force_data.force[start_idx:end_idx]
print(start_idx, end_idx)

force_data_np = np.zeros((len(force_precision), 7))
for i in range(len(force_precision)):
    data = force_precision[i]
    force_data_np[i] = [int(data.timestamp.split('.')[0]), data.force.x, data.force.y, data.force.z, data.torque.x, data.torque.y, data.torque.z]

print(force_data_np.shape)
force_data_np[:, 0] = (force_data_np[:, 0] - force_data_np[0, 0]) * (10**-9)
fig, axs = plt.subplots(2, 3, figsize=(18, 10))
axs[0, 0].plot(force_data_np[:, 0], force_data_np[:, 1], label='Fx')
axs[0, 0].set_title('Fx')
axs[0, 1].plot(force_data_np[:, 0], force_data_np[:, 2], label='Fy')
axs[0, 1].set_title('Fy')
axs[0, 2].plot(force_data_np[:, 0], force_data_np[:, 3], label='Fz')
axs[0, 2].set_title('Fz')
axs[1, 0].plot(force_data_np[:, 0], force_data_np[:, 4], label='Tx')
axs[1, 0].set_title('Tx')
axs[1, 1].plot(force_data_np[:, 0], force_data_np[:, 5], label='Ty')
axs[1, 1].set_title('Ty')
axs[1, 2].plot(force_data_np[:, 0], force_data_np[:, 6], label='Tz')
axs[1, 2].set_title('Tz')
plt.show()
# Out:
# 252957 352845
# (99888, 7)

# %%
t_start = test_cmd_slipping[0, 0]
t_end = test_cmd_slipping[-1, 0]

start_idx = -1
end_idx = -1
for i in range(len(force_data.force)):
    if start_idx == -1 and int(force_data.force[i].timestamp.split('.')[0]) > t_start:
        start_idx = i
    if end_idx == -1 and int(force_data.force[i].timestamp.split('.')[0]) > t_end:
        end_idx = i
        break

force_slipping = force_data.force[start_idx:end_idx]
print(start_idx, end_idx)

force_data_np = np.zeros((len(force_slipping), 7))
for i in range(len(force_slipping)):
    data = force_slipping[i]
    force_data_np[i] = [int(data.timestamp.split('.')[0]), data.force.x, data.force.y, data.force.z, data.torque.x, data.torque.y, data.torque.z]

print(force_data_np.shape)
force_data_np[:, 0] = (force_data_np[:, 0] - force_data_np[0, 0]) * (10**-9)
fig, axs = plt.subplots(2, 3, figsize=(18, 10))
axs[0, 0].plot(force_data_np[:, 0], force_data_np[:, 1], label='Fx')
axs[0, 0].set_title('Fx')
axs[0, 1].plot(force_data_np[:, 0], force_data_np[:, 2], label='Fy')
axs[0, 1].set_title('Fy')
axs[0, 2].plot(force_data_np[:, 0], force_data_np[:, 3], label='Fz')
axs[0, 2].set_title('Fz')
axs[1, 0].plot(force_data_np[:, 0], force_data_np[:, 4], label='Tx')
axs[1, 0].set_title('Tx')
axs[1, 1].plot(force_data_np[:, 0], force_data_np[:, 5], label='Ty')
axs[1, 1].set_title('Ty')
axs[1, 2].plot(force_data_np[:, 0], force_data_np[:, 6], label='Tz')
axs[1, 2].set_title('Tz')
plt.show()
# Out:
# 352974 553285
# (200311, 7)

# %%
pose_pressing = cmd_pressing.replace('cmd', 'pose')
pose_precision = cmd_precision.replace('cmd', 'pose')
pose_slipping = cmd_slipping.replace('cmd', 'pose')
print(pose_pressing, pose_precision, pose_slipping)
print(cmd_dir)
# Out:
# c_rigid_concave_pose_pressing_0.csv c_rigid_concave_pose_precision_0.csv c_rigid_concave_pose_slipping_0.csv
# /home/hrg/ws_moveit/data/short_rigid_letters/kinova/

# %%
test_pose_pressing = genfromtxt(cmd_dir + pose_pressing, delimiter=',')
test_pose_precision = genfromtxt(cmd_dir + pose_precision, delimiter=',')
test_pose_slipping = genfromtxt(cmd_dir + pose_slipping, delimiter=',')

fig, axs = plt.subplots(2, 2, figsize=(12, 10))
t_cmd = (test_cmd_pressing[:, 0] - test_cmd_pressing[0, 0]) * (10**-9)
speed_z = test_cmd_pressing[:, 3]
pose_z = np.zeros(test_cmd_pressing.shape[0])
dt = 0.01
for i in range(test_cmd_pressing.shape[0]-1):
  dt = t_cmd[i+1] - t_cmd[i]
  pose_z[i+1] = pose_z[i] + speed_z[i]*dt

axs[0, 0].plot(t_cmd, speed_z)
axs[0, 0].set_title('Speed')
axs[0, 1].plot(t_cmd, pose_z)
axs[0, 1].set_title('Pose')

t_pose = (test_pose_pressing[:, 0] - test_pose_pressing[0, 0]) * (10**-9)
real_z = test_pose_pressing[:, 3]
real_v_z = np.zeros(test_pose_pressing.shape[0])
for i in range(test_pose_pressing.shape[0]-1):
  dt = t_pose[i+1] - t_pose[i]
  real_v_z[i+1] = (real_z[i+1] - real_z[i]) / dt

axs[1, 0].plot(t_pose, real_v_z)
axs[1, 0].set_title('Real Speed')
axs[1, 1].plot(t_pose, real_z)
axs[1, 1].set_title('Real Pose')
# Out:
# Text(0.5, 1.0, 'Real Pose')

# %%
fig, axs = plt.subplots(2, 3, figsize=(18, 10))
t_cmd = (test_cmd_precision[:, 0] - test_cmd_precision[0, 0]) * (10**-9)
axs[0, 0].plot(t_cmd, test_cmd_precision[:, 1])
axs[0, 0].set_title('linear_x')
axs[0, 1].plot(t_cmd, test_cmd_precision[:, 2])
axs[0, 1].set_title('linear_y')
axs[0, 2].plot(t_cmd, test_cmd_precision[:, 3])
axs[0, 2].set_title('linear_z')
axs[1, 0].plot(t_cmd, test_cmd_precision[:, 4])
axs[1, 0].set_title('angular_x')
axs[1, 1].plot(t_cmd, test_cmd_precision[:, 5])
axs[1, 1].set_title('angular_y')
axs[1, 2].plot(t_cmd, test_cmd_precision[:, 6])
axs[1, 2].set_title('angular_z')
# Out:
# Text(0.5, 1.0, 'angular_z')

# %%
fig, axs = plt.subplots(2, 3, figsize=(18, 10))
t_pose = (test_pose_precision[:, 0] - test_pose_precision[0, 0]) * (10**-9)
axs[0, 0].plot(t_pose, test_pose_precision[:, 1])
axs[0, 0].set_title('pos_x')
axs[0, 1].plot(t_pose, test_pose_precision[:, 2])
axs[0, 1].set_title('pos_y')
axs[0, 2].plot(t_pose, test_pose_precision[:, 3])
axs[0, 2].set_title('pos_z')
axs[1, 0].plot(t_pose, test_pose_precision[:, 4])
axs[1, 0].set_title('euler_x')
axs[1, 1].plot(t_pose, test_pose_precision[:, 5])
axs[1, 1].set_title('euler_y')
axs[1, 2].plot(t_pose, test_pose_precision[:, 6])
axs[1, 2].set_title('euler_z')
# Out:
# Text(0.5, 1.0, 'euler_z')

# %%
t_cmd = (test_cmd_slipping[:, 0] - test_cmd_slipping[0, 0]) * (10**-9)
fig, axs = plt.subplots(2, 3, figsize=(18, 10))
axs[0, 0].plot(t_cmd, test_cmd_slipping[:, 1])
axs[0, 0].set_title('linear_x')
axs[0, 1].plot(t_cmd, test_cmd_slipping[:, 2])
axs[0, 1].set_title('linear_y')
axs[0, 2].plot(t_cmd, test_cmd_slipping[:, 3])
axs[0, 2].set_title('linear_z')
axs[1, 0].plot(t_cmd, test_cmd_slipping[:, 4])
axs[1, 0].set_title('angular_x')
axs[1, 1].plot(t_cmd, test_cmd_slipping[:, 5])
axs[1, 1].set_title('angular_y')
axs[1, 2].plot(t_cmd, test_cmd_slipping[:, 6])
axs[1, 2].set_title('angular_z')
# Out:
# Text(0.5, 1.0, 'angular_z')

# %%
fig, axs = plt.subplots(2, 3, figsize=(18, 10))
t_pose = (test_pose_slipping[:, 0] - test_pose_slipping[0, 0]) * (10**-9)
axs[0, 0].plot(t_pose, test_pose_slipping[:, 1])
axs[0, 0].set_title('pos_x')
axs[0, 1].plot(t_pose, test_pose_slipping[:, 2])
axs[0, 1].set_title('pos_y')
axs[0, 2].plot(t_pose, test_pose_slipping[:, 3])
axs[0, 2].set_title('pos_z')
axs[1, 0].plot(t_pose, test_pose_slipping[:, 4])
axs[1, 0].set_title('euler_x')
axs[1, 1].plot(t_pose, test_pose_slipping[:, 5])
axs[1, 1].set_title('euler_y')
axs[1, 2].plot(t_pose, test_pose_slipping[:, 6])
axs[1, 2].set_title('euler_z')
# Out:
# Text(0.5, 1.0, 'euler_z')
